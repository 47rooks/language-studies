# %% [markdown]
# # Text Sizes Documentation and Validation Checks

# %% [markdown]
# #### Some notebook setup

# %%
# %%javascript
# require("notebook/js/outputarea").OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 2000)

# Import module with functions to work with the data files
import os
import sys
module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
print("sys.path={}".format(sys.path))

from languagestudies import utilities as lsut
# Out:
# sys.path=['', 'D:\\UserData\\Daniel\\Miniconda3\\python36.zip', 'D:\\UserData\\Daniel\\Miniconda3\\DLLs', 'D:\\UserData\\Daniel\\Miniconda3\\lib', 'D:\\UserData\\Daniel\\Miniconda3', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages\\win32', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages\\win32\\lib', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages\\Pythonwin', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages\\setuptools-27.2.0-py3.6.egg', 'D:\\UserData\\Daniel\\Miniconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Daniel\\.ipython', 'D:\\UserData\\Daniel\\github\\language-studies\\language-studies', 'D:\\UserData\\Daniel\\github\\language-studies']

# %% [markdown]
# ### Description
#
# The Text Sizes.csv file contains text sizes in number of words by text and section, usually book or work. In addition there is a special value in the Section field indicating the total number of words in the work as a whole. The is the ```__ALL__``` value. All these values are from Accordance version 12 and the various Greek works I own in Accordance at this time.
#
# |Field | Description |
# |:----- |:----------- |
# |Author | The approximate or commonly assumed author. This not populated with any critically authoritative information. See note below.|
# |Text |This is the text module name in Accordance.|
# |Section|This the book or section name.|
# |Total Words|This is the total number of words in the section. Where Section == ```__ALL__``` it is the total number of words in the Text.|
# |IncludedInTotal|True if this row's Total Words are included in the ```__ALL__``` value. Must be False for ```__ALL__```, and for any other sections not included.|
# |AccWorkspace|The Accordance workspace name in the repo. used to produce the data.|
#
# Note, the Author field is only of any value in some cases. In the investigation that spawned the creation of this data I was looking at works by Luke. In many cases, I have listed the Author as Various or Unknown. It is debatable that the field should even be present.
#
# Date data collected : 16th March 2019.

# %%
import pandas as pd
size_data = pd.read_csv("../data/Text Sizes.csv")

# %% [markdown]
# The texts in the data are these.

# %%
sorted(size_data['Text'].drop_duplicates())
# Out:
# ['Apostolic Fathers Greek',
#  'Athanasius Greek',
#  'Basil Greek',
#  'Epictetus Greek',
#  'Gospel of Thomas (Greek)',
#  'Gregory Greek',
#  'Gregory of Nyssa (Greek)',
#  'Josephus Greek',
#  'LXX Rahlfs Tagged',
#  'LXX Swete',
#  'LXX Swete (Enoch)',
#  'LXX Swete (parallel texts)',
#  'NA28 GNT',
#  'Philo Greek',
#  'Pseudepigrapha Greek',
#  'Pseudo-Clem. Homilies Greek']

# %% [markdown]
# ### Validation Checks
# This section includes a variety of validation checks on the data.

# %% [markdown]
# Make sure that ``__ALL__`` rows are marked as IncludedInTotal=False

# %%
if (size_data.query('IncludedInTotal == True and Section == \'__ALL__\'').empty):
      print('__ALL__ rows are all marked IncludedInTotal=False')
else:
    print('The following __ALL__ rows are incorrectly included in totals:')
    print(size_data.query('IncludedInTotal == True and Section == \'__ALL__\''))
# Out:
# __ALL__ rows are all marked IncludedInTotal=False

# %% [markdown]
# These validation checks just validate that summing up all sections for a work, where IncludedInTotal == True, matches the ```__ALL__``` total for the work.

# %%
# Compute totals and compare with __ALL__ values
# Compute totals using only included values
total_sizes = size_data.query('IncludedInTotal == True')[['Text','Total Words']].groupby(['Text']).sum()
total_sizes.reset_index(inplace=True)
total_sizes.columns=['Text','Aggregated Total']

# Extract the __ALL__ values
__all__sizes = size_data.query('Section == \'__ALL__\'')[['Text','Total Words']]
__all__sizes.columns=['Text', '__ALL__ Words']
compare_sizes = total_sizes.join(__all__sizes.set_index(['Text']), on=['Text'])
compare_sizes['Diff'] = compare_sizes['Aggregated Total'] != compare_sizes['__ALL__ Words']
compare_sizes
# Out:
#                            Text  Aggregated Total  __ALL__ Words   Diff
# 0       Apostolic Fathers Greek             66264          66264  False
# 1              Athanasius Greek            146844         146844  False
# 2                   Basil Greek             25899          25899  False
# 3               Epictetus Greek             80305          80305  False
# 4      Gospel of Thomas (Greek)              2665           2665  False
# 5                 Gregory Greek              9747           9747  False
# 6      Gregory of Nyssa (Greek)             20359          20359  False
# 7                Josephus Greek            468505         468505  False
# 8             LXX Rahlfs Tagged            587477         587477  False
# 9                     LXX Swete            583665         583665  False
# 10            LXX Swete (Enoch)              5716           5716  False
# 11   LXX Swete (parallel texts)             19433          19433  False
# 12                     NA28 GNT            138213         138213  False
# 13                  Philo Greek            438608         438608  False
# 14         Pseudepigrapha Greek            172645         172645  False
# 15  Pseudo-Clem. Homilies Greek             74950          74950  False

# %% [markdown]
# Overall text sizes by various aggregations.

# %%
# Example dumps
print("Total size by text")
print(lsut.get_text_total_sizes())
print("\nTotal size by text and section")
print(lsut.get_section_total_sizes())
print("\nTotal size by author")
print(lsut.get_author_total_sizes())
# Out:
# Total size by text
#                            Text  Total Words
# 0       Apostolic Fathers Greek        66264
# 1              Athanasius Greek       146844
# 2                   Basil Greek        25899
# 3               Epictetus Greek        80305
# 4      Gospel of Thomas (Greek)         2665
# 5                 Gregory Greek         9747
# 6      Gregory of Nyssa (Greek)        20359
# 7                Josephus Greek       468505
# 8             LXX Rahlfs Tagged       587477
# 9                     LXX Swete       583665
# 10            LXX Swete (Enoch)         5716
# 11   LXX Swete (parallel texts)        19433
# 12                     NA28 GNT       138213
# 13                  Philo Greek       438608
# 14         Pseudepigrapha Greek       172645
# 15  Pseudo-Clem. Homilies Greek        74950
#
# Total size by text and section
#                             Text         Section  Total Words
# 0                 Josephus Greek          Antiq.       306488
# 1                 Josephus Greek             War       125595
# 2                 Josephus Greek            Life        15836
# 3                 Josephus Greek           Apion        20586
# 5              LXX Rahlfs Tagged         Genesis        32572
# 6              LXX Rahlfs Tagged          Exodus        24818
# 68                   Philo Greek            Opif        13342
# 69                   Philo Greek           Legum        31666
# 70                   Philo Greek            Cher         7569
# 71                   Philo Greek            Sacr         9476
# 72                   Philo Greek             Det        11214
# 73                   Philo Greek            Post        10978
# 74                   Philo Greek             Gig         3255
# 75                   Philo Greek            Deus         8932
# 76                   Philo Greek             Agr         9013
# 77                   Philo Greek           Plant         8888
# 78                   Philo Greek             Ebr        11535
# 79                   Philo Greek            Sobr         3579
# 80                   Philo Greek            Conf        10274
# 81                   Philo Greek            Migr        12471
# 82                   Philo Greek             Her        15701
# 83                   Philo Greek           Congr         8839
# 84                   Philo Greek             Fug        10883
# 85                   Philo Greek             Mut        13023
# 86                   Philo Greek            Somn        25846
# 87                   Philo Greek             Abr        13310
# 88                   Philo Greek             Ios        12846
# 89                   Philo Greek            Moys        31452
# 90                   Philo Greek           Decal         8459
# 91                   Philo Greek            Spec        56900
# 92                   Philo Greek            Virt        12202
# 93                   Philo Greek           Praem         9099
# 94                   Philo Greek            Prob         7639
# 95                   Philo Greek        Contempl         4604
# 96                   Philo Greek             Aet         9220
# 97                   Philo Greek           Flacc         8931
# 98                   Philo Greek           Legat        17519
# 99                   Philo Greek          Hypoth         2349
# 100                  Philo Greek            Prov         4225
# 101                  Philo Greek           1QGen         8252
# 102                  Philo Greek           2QGen          637
# 103                  Philo Greek           3QGen         1090
# 104                  Philo Greek            1QEx         2239
# 105                  Philo Greek            2QEx         1151
# 107                     NA28 GNT         Matthew        18365
# 108                     NA28 GNT            Mark        11314
# 109                     NA28 GNT            Luke        19497
# 110                     NA28 GNT            John        15673
# 111                     NA28 GNT            Acts        18472
# 112                     NA28 GNT          1 Acts        10063
# 113                     NA28 GNT          2 Acts         8409
# 114                     NA28 GNT          Romans         7116
# 115                     NA28 GNT    1Corinthians         6843
# 116                     NA28 GNT    2Corinthians         4491
# 117                     NA28 GNT       Galatians         2235
# 118                     NA28 GNT       Ephesians         2425
# 119                     NA28 GNT     Philippians         1633
# 120                     NA28 GNT      Colossians         1583
# 121                     NA28 GNT  1Thessalonians         1485
# 122                     NA28 GNT  2Thessalonians          826
# 123                     NA28 GNT        1Timothy         1594
# 124                     NA28 GNT        2Timothy         1242
# 125                     NA28 GNT           Titus          661
# 126                     NA28 GNT        Philemon          337
# 127                     NA28 GNT         Hebrews         4958
# 128                     NA28 GNT           James         1748
# 129                     NA28 GNT          1Peter         1683
# 130                     NA28 GNT          2Peter         1102
# 131                     NA28 GNT           1John         2143
# 132                     NA28 GNT           2John          248
# 133                     NA28 GNT           3John          221
# 134                     NA28 GNT            Jude          460
# 135                     NA28 GNT      Revelation         9858
# 137      Apostolic Fathers Greek          1Clem.         9889
# 138      Apostolic Fathers Greek          2Clem.         3018
# 139      Apostolic Fathers Greek            Eph.         1777
# 140      Apostolic Fathers Greek            Mag.         1060
# 141      Apostolic Fathers Greek           Tral.          956
# 142      Apostolic Fathers Greek            Rom.         1029
# 143      Apostolic Fathers Greek          Phila.         1020
# 207         Pseudepigrapha Greek      History_J.          400
# 208         Pseudepigrapha Greek           3Mac.         5080
# 209         Pseudepigrapha Greek           4Mac.         7908
# 210         Pseudepigrapha Greek         Phocyl.         1585
# 211         Pseudepigrapha Greek     Prayer_Jos.          276
# 212         Pseudepigrapha Greek     Prayer_Man.          481
# 213         Pseudepigrapha Greek     Prayer_Jac.          259
# 214         Pseudepigrapha Greek        Ode_Sol.          335
# 215         Pseudepigrapha Greek         Ps_Sol.         4927
# 216         Pseudepigrapha Greek           Philo          236
# 217         Pseudepigrapha Greek          Theod.          706
# 218         Pseudepigrapha Greek           Orph.          728
# 219         Pseudepigrapha Greek   Ezekiel_Trag.         1642
# 220         Pseudepigrapha Greek        Aristob.         2020
# 221         Pseudepigrapha Greek         Demetr.         1507
# 222         Pseudepigrapha Greek       Arist_Job          336
# 223         Pseudepigrapha Greek        Eupolem.         1692
# 224         Pseudepigrapha Greek   Pseudo_Eupol.          451
# 225         Pseudepigrapha Greek        Cleodem.          286
# 226         Pseudepigrapha Greek        Artapan.         1769
# 227         Pseudepigrapha Greek   Pseudo_Hecat.         1146
# 228         Pseudepigrapha Greek        Ord_Levi         1299
# 229         Pseudepigrapha Greek     Prayer_Levi          307
# 230         Pseudepigrapha Greek        Rich_Man          287
# 231         Pseudepigrapha Greek       Prophetic           64
# 232         Pseudepigrapha Greek     Apocalyptic           91
# 233         Pseudepigrapha Greek      Exorcism_A          483
# 234         Pseudepigrapha Greek      Exorcism_B          483
# 235         Pseudepigrapha Greek           Zech.          125
# 237                    LXX Swete         Genesis        32635
# 238                    LXX Swete          Exodus        24636
# 239                    LXX Swete       Leviticus        19042
# 240                    LXX Swete         Numbers        25000
# 241                    LXX Swete     Deuteronomy        22513
# 242                    LXX Swete          Joshua        14858
# 243                    LXX Swete          Judges        15589
# 244                    LXX Swete            Ruth         2061
# 245                    LXX Swete         1Samuel        20067
# 246                    LXX Swete         2Samuel        17907
# 247                    LXX Swete          1Kings        20488
# 248                    LXX Swete          2Kings        18637
# 249                    LXX Swete     1Chronicles        15962
# 250                    LXX Swete     2Chronicles        21102
# 251                    LXX Swete         1Esdras         8808
# 252                    LXX Swete            Ezra         5340
# 253                    LXX Swete        Nehemiah         7359
# 254                    LXX Swete          Psalms        34787
# 255                    LXX Swete        Proverbs        11095
# 256                    LXX Swete    Ecclesiastes         4529
# 257                    LXX Swete            Song         2001
# 258                    LXX Swete             Job        13516
# 259                    LXX Swete          Wisdom         6934
# 260                    LXX Swete          Sirach        18691
# 261                    LXX Swete          Esther         5832
# 262                    LXX Swete          Judith         9117
# 263                    LXX Swete           Tobit         5459
# 264                    LXX Swete           Hosea         3920
# 265                    LXX Swete            Amos         3201
# 266                    LXX Swete           Micah         2344
# 267                    LXX Swete            Joel         1574
# 268                    LXX Swete         Obadiah          456
# 269                    LXX Swete           Jonah         1080
# 270                    LXX Swete           Nahum          932
# 271                    LXX Swete        Habakkuk         1091
# 272                    LXX Swete       Zephaniah         1222
# 273                    LXX Swete          Haggai          948
# 274                    LXX Swete       Zechariah         4957
# 275                    LXX Swete         Malachi         1409
# 276                    LXX Swete          Isaiah        26981
# 277                    LXX Swete        Jeremiah        28786
# 278                    LXX Swete          Baruch         2600
# 279                    LXX Swete    Lamentations         2464
# 280                    LXX Swete  Letterjeremiah         1285
# 281                    LXX Swete         Ezekiel        29405
# 282                    LXX Swete          Daniel        10961
# 283                    LXX Swete         Susanna          885
# 284                    LXX Swete             Bel          901
# 285                    LXX Swete      1Maccabees        18293
# 286                    LXX Swete      2Maccabees        11876
# 287                    LXX Swete      3Maccabees         5079
# 288                    LXX Swete      4Maccabees         7909
# 289                    LXX Swete         Solomon         4931
# 290                    LXX Swete            Odes         4210
# 292   LXX Swete (parallel texts)           Tobit         7148
# 293   LXX Swete (parallel texts)          Daniel        10290
# 294   LXX Swete (parallel texts)         Susanna         1130
# 295   LXX Swete (parallel texts)             Bel          865
# 297            LXX Swete (Enoch)           Enoch         5716
# 299  Pseudo-Clem. Homilies Greek            Jam.          496
# 300  Pseudo-Clem. Homilies Greek           Test.          668
# 301  Pseudo-Clem. Homilies Greek           Clem.         2517
# 302  Pseudo-Clem. Homilies Greek           1Hom.         3565
# 303  Pseudo-Clem. Homilies Greek           2Hom.         5778
# 304  Pseudo-Clem. Homilies Greek           3Hom.         7717
# 305  Pseudo-Clem. Homilies Greek           4Hom.         2528
# 306  Pseudo-Clem. Homilies Greek           5Hom.         3329
# 307  Pseudo-Clem. Homilies Greek           6Hom.         3373
# 308  Pseudo-Clem. Homilies Greek           7Hom.         1459
# 309  Pseudo-Clem. Homilies Greek           8Hom.         2839
# 310  Pseudo-Clem. Homilies Greek           9Hom.         2709
# 311  Pseudo-Clem. Homilies Greek          10Hom.         2933
# 312  Pseudo-Clem. Homilies Greek          11Hom.         4570
# 313  Pseudo-Clem. Homilies Greek          12Hom.         4762
# 314  Pseudo-Clem. Homilies Greek          13Hom.         2790
# 315  Pseudo-Clem. Homilies Greek          14Hom.         1885
# 316  Pseudo-Clem. Homilies Greek          15Hom.         1622
# 317  Pseudo-Clem. Homilies Greek          16Hom.         3313
# 318  Pseudo-Clem. Homilies Greek          17Hom.         3610
# 319  Pseudo-Clem. Homilies Greek          18Hom.         3548
# 320  Pseudo-Clem. Homilies Greek          19Hom.         4731
# 321  Pseudo-Clem. Homilies Greek          20Hom.         4208
# 323              Epictetus Greek         Enchir.         5002
# 324              Epictetus Greek          Arrian          200
# 325              Epictetus Greek          1Disc.        18218
# 326              Epictetus Greek          2Disc.        19798
# 327              Epictetus Greek          3Disc.        20190
# 328              Epictetus Greek          4Disc.        16897
#
# Total size by author
#                  Author  Total Words
# 0            Athanasius       146844
# 1       Basil the Great        25899
# 2             Epictetus        80305
# 3  Gregory of Nazianzus         9747
# 4      Gregory of Nyssa        20359
# 5              Josephus       468505
# 6                  Luke        37969
# 7                 Philo       438608
# 8               Unknown        77615
# 9               Various      1553916
